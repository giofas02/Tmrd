# %% [markdown]
# # Proviamo a fare l'analisi del coviddi

# %% [markdown]
# 1. Per prima cosa voglio leggere i dati, inserendoli in una tabella

# %%
import numpy as np
import matplotlib.pyplot as mp
import pandas as pd

coviddi = pd.read_csv('dpc-covid19-ita-regioni.csv', index_col = 'data', parse_dates = True, sep = ',')

# %%
coviddi.head
# Out:
# <bound method NDFrame.head of                     stato  codice_regione denominazione_regione        lat  \
# data
# 2020-02-24 18:00:00   ITA              13               Abruzzo  42.351222
# 2020-02-24 18:00:00   ITA              17            Basilicata  40.639471
# 2020-02-24 18:00:00   ITA              18              Calabria  38.905976
# 2020-02-24 18:00:00   ITA              15              Campania  40.839566
# 2020-02-24 18:00:00   ITA               8        Emilia-Romagna  44.494367
# ...                   ...             ...                   ...        ...
# 2023-10-25 17:00:00   ITA              19               Sicilia  38.115697
# 2023-10-25 17:00:00   ITA               9               Toscana  43.769231
# 2023-10-25 17:00:00   ITA              10                Umbria  43.106758
# 2023-10-25 17:00:00   ITA               2         Valle d'Aosta  45.737503
# 2023-10-25 17:00:00   ITA               5                Veneto  45.434905
#
# ...

# %%
coviddi.columns
# Out:
# Index(['stato', 'codice_regione', 'denominazione_regione', 'lat', 'long',
#        'ricoverati_con_sintomi', 'terapia_intensiva', 'totale_ospedalizzati',
#        'isolamento_domiciliare', 'totale_positivi',
#        'variazione_totale_positivi', 'nuovi_positivi', 'dimessi_guariti',
#        'deceduti', 'casi_da_sospetto_diagnostico', 'casi_da_screening',
#        'totale_casi', 'tamponi', 'casi_testati', 'note',
#        'ingressi_terapia_intensiva', 'note_test', 'note_casi',
#        'totale_positivi_test_molecolare',
#        'totale_positivi_test_antigenico_rapido', 'tamponi_test_molecolare',
#        'tamponi_test_antigenico_rapido', 'codice_nuts_1', 'codice_nuts_2'],
#       dtype='object')

# %%
coviddi.denominazione_regione
# Out:
# data
# 2020-02-24 18:00:00           Abruzzo
# 2020-02-24 18:00:00        Basilicata
# 2020-02-24 18:00:00          Calabria
# 2020-02-24 18:00:00          Campania
# 2020-02-24 18:00:00    Emilia-Romagna
#                             ...
# 2023-10-25 17:00:00           Sicilia
# 2023-10-25 17:00:00           Toscana
# 2023-10-25 17:00:00            Umbria
# 2023-10-25 17:00:00     Valle d'Aosta
# 2023-10-25 17:00:00            Veneto
# Name: denominazione_regione, Length: 28140, dtype: object

# %% [markdown]
# 2. Una volta letta correttamente la tabella, proviamo a fare cose a caso
# Ad esempio qui dico per ogni regione, conta quanti dati ho (NOTA: nei dati complessivi, ad ogni ora vengono scritti per ogni regione quanti ricoverati ho con sintomi.. quindi di fatto quello che mi dice è per ogni regione quante ore son state esaminate), e fa la media: sommo tutti i dati (numero ricoveri) per regione e divide per 1340.

# %%
coviddi.groupby('denominazione_regione')['ricoverati_con_sintomi'].aggregate(['count','mean'])
# Out:
#                        count         mean
# denominazione_regione
# Abruzzo                 1340   194.429851
# Basilicata              1340    47.855224
# Calabria                1340   161.121642
# Campania                1340   531.174627
# Emilia-Romagna          1340  1051.800000
# Friuli Venezia Giulia   1340   172.504478
# Lazio                   1340   907.799254
# Liguria                 1340   290.801493
# Lombardia               1340  1776.876119
# Marche                  1340   184.960448
# Molise                  1340    17.632090
# P.A. Bolzano            1340    68.012687
# P.A. Trento             1340    74.893284
# Piemonte                1340   917.323134
# Puglia                  1340   419.076866
# Sardegna                1340   159.479851
# Sicilia                 1340   518.757463
# Toscana                 1340   467.352985
# Umbria                  1340   131.251493
# Valle d'Aosta           1340    22.048507
# Veneto                  1340   596.942537

# %% [markdown]
# 3. Faccio delle nuove tabelle con i dati che mi interessano solamente

# %%
coviddi1 = coviddi[['denominazione_regione', 'totale_positivi','isolamento_domiciliare']]
coviddi2 = coviddi[['denominazione_regione', 'totale_casi','dimessi_guariti']]
coviddi3 = coviddi[['denominazione_regione', 'deceduti']]


for i, (reg,valori) in enumerate(coviddi1.groupby('denominazione_regione')): #scorro le coppie (regione,valori) dove i valori sono tot positivi e isolamento
    #print(reg) - il groupby mi fa tante tabelle (una per regione, che è il primo indice, cioè reg) con i valori di coviddi1
    #print(valori) 
    if reg == 'Veneto': #se la reg è Veneto inseriscilo nella tabella di coppie (reg,valori)
        datiVeneto1 = valori.drop(['denominazione_regione'],axis = 1 ) #elimina la colonna con la regione
        
for (reg,valori) in (coviddi2.groupby('denominazione_regione')): #posso fare anche senza enumerate!
    if reg == 'Veneto':
        datiVeneto2 = valori.drop(['denominazione_regione'],axis = 1 )
        
for i, (reg,valori) in enumerate(coviddi3.groupby('denominazione_regione')):
    if reg == 'Veneto': 
        datiVeneto3 = valori.drop(['denominazione_regione'],axis = 1 )

print(datiVeneto1)
print(datiVeneto2)
print(datiVeneto3)
# Out:
#                      totale_positivi  isolamento_domiciliare
# data
# 2020-02-24 18:00:00               32                      16
# 2020-02-25 18:00:00               42                      23
# 2020-02-26 18:00:00               69                      45
# 2020-02-27 18:00:00              109                      82
# 2020-02-28 18:00:00              149                     116
# ...                              ...                     ...
# 2023-10-21 17:00:00             8312                    7984
# 2023-10-22 17:00:00             7615                    7289
# 2023-10-23 17:00:00             7185                    6861
# 2023-10-24 17:00:00             7846                    7532
# 2023-10-25 17:00:00             8045                    7704
#
# [1340 rows x 2 columns]
#                      totale_casi  dimessi_guariti
# data
# 2020-02-24 18:00:00           33                0
# 2020-02-25 18:00:00           43                0
# ...

# %% [markdown]
#  4. Facciamo ora i grafici dei nuovi positivi del Veneto (asse y) per data (asse x)

# %%
datiVeneto1.plot()
datiVeneto2.plot()
datiVeneto3.plot()
# Out:
# <Axes: xlabel='data'>

# %% [markdown]
# 5. Supponiamo ora di voler raggruppare (si usa la funzione sum) le date annualmente, mensilmente o giornalmente

# %%
datiVeneto1yearly = datiVeneto1.resample('Y').sum()
datiVeneto1yearly.plot(style = ['-',':'])
# Out:
# <Axes: xlabel='data'>

# %%
datiVeneto1monthly = datiVeneto1.resample('M').sum()
datiVeneto1monthly.plot(style = ['-','.'])
# Out:
# <Axes: xlabel='data'>

# %%
datiVeneto1daily = datiVeneto1.resample('D').sum()
datiVeneto1daily.plot(style = ['--','.'])
# Out:
# <Axes: xlabel='data'>

# %% [markdown]
# 6. Proviamo a fare le stesse cose utilizzando le classi

# %%
class tabdatadati:
    
    def __init__(self,dati,regione,dato1,stilegrafico):
        self.tabella =  pd.read_csv(dati, sep =',',index_col = 'data', parse_dates = True)
        self.dato = self.tabella[[dato1]]
        for (reg,valori) in (self.tabella.groupby('denominazione_regione')): 
            if reg == regione:
                self.regione = valori.drop(['denominazione_regione'],axis = 1)
        self.datoregione = self.regione[[dato1]]
        self.datoregione.plot(style = stilegrafico)
        
coviddi = tabdatadati('dpc-covid19-ita-regioni.csv','Friuli Venezia Giulia','totale_positivi',':')
#print(coviddi.tabella)
#print(coviddi.dato)
#print(coviddi.regione.head)
#print(coviddi.datoregione)
datiVeneto1daily = coviddi.datoregione.resample('M').sum()
datiVeneto1daily.plot(style = '--')
# Out:
# <Axes: xlabel='data'>
